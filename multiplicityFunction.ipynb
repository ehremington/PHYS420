# %% [markdown]
# ## import statements

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.special as sp

# %% [markdown]
# ## define some helpful functions

# %%
def factorial(x):
    return sp.factorial(x, exact=True)

# %%
def combination(N,q):
    return factorial(q+N-1)//factorial(q)//factorial(N-1)

# %%
combination(500,100)
# Out:
# 92617601588848787700794369127348784356121334262853897042393434278491595498450019668972021860619724231355309579374480

# %% [markdown]
# ## Two Einstein Solids
# ### 3 particles each and 6 energy units

# %%
round1 = pd.DataFrame({'q_A':range(0, 6+1, 1),'q_B':range(6,0-1,-1)})

round1['multi_A'] = [combination(3,i) for i in round1['q_A']]

round1['multi_B'] = [combination(3,i) for i in round1['q_B']]

round1['multi_total'] = round1['multi_A']*round1['multi_B']

round1
# Out:
#    q_A  q_B  multi_A  multi_B  multi_total
# 0    0    6        1       28           28
# 1    1    5        3       21           63
# 2    2    4        6       15           90
# 3    3    3       10       10          100
# 4    4    2       15        6           90
# 5    5    1       21        3           63
# 6    6    0       28        1           28

# %% [markdown]
# #### how many total microstates from the above situation?

# %%
round1['multi_total'].sum()
# Out:
# 462

# %% [markdown]
# ##### most likely macrostate

# %%
round1.sort_values('multi_total', ascending=False).iloc[0]
# Out:
# q_A              3
# q_B              3
# multi_A         10
# multi_B         10
# multi_total    100
# Name: 3, dtype: int64

# %% [markdown]
# ## Now prepare a function to scale this up to large numbers

# %%
def multiTable(N_a, N_b, q):
    round1 = pd.DataFrame({'q_A':range(0, q+1, 1),'q_B':range(q, 0-1,-1)})

    round1['multi_A'] = [combination(N_a, i) for i in round1['q_A']]

    round1['multi_B'] = [combination(N_b, i) for i in round1['q_B']]

    round1['multi_total'] = round1['multi_A']*round1['multi_B']

    return round1

# %% [markdown]
# ### Try with Na = 300, Nb = 200, q = 100

# %%
round2 = multiTable(300, 200, 100)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.bar(round2['q_A'], round2['multi_total'])
# Out:
# FigureCanvasNbAgg()
# <BarContainer object of 101 artists>

# %%
total = round2['multi_total'].sum()
total
# Out:
# 92617601588848787700794369127348784356121334262853897042393434278491595498450019668972021860619724231355309579374480

# %%
round2.sort_values('multi_total', ascending=False).iloc[0]
# Out:
# q_A                                                           60
# q_B                                                           40
# multi_A        1303374942856697976788022297481731862105814167...
# multi_B           5268096860471741104075796421254209692157813745
# multi_total    6866305444480905576053279924558993308220523651...
# Name: 60, dtype: object

# %%
multi_max = round2['multi_total'].sort_values(ascending=False).iloc[0]
multi_max
# Out:
# 6866305444480905576053279924558993308220523651304617917299213619156097955189326582542084987815980676571073623010600

# %%
multi_max/total
# Out:
# 0.07413607485715343

# %%
round2['multi_total'].sort_values(axis=0,ascending=False)
# Out:
# 200    9198906474730773500498449838275611544890059638...
# 199    9171483738353097738261049300866022138695360510...
# 201    9171483738353097738261049300866022138695360510...
# 202    9089702942761794618144740886785175764501458780...
# 198    9089702942761794618144740886785175764501458780...
# 197    8955011980243543406895705912151721464633981197...
# 203    8955011980243543406895705912151721464633981197...
# 196    8769776764452017707668232077611344003518795766...
# 204    8769776764452017707668232077611344003518795766...
# 195    8537212396153024067349580069522138517305747435...
# 12    12  488  1.38E+21 1.24E+178    1.71E+199
# 13    13  487  3.31E+22 8.82E+177    2.92E+200
# 14    14  486  7.40E+23 6.26E+177    4.63E+201
# 15    15  485  1.55E+25 4.44E+177    6.88E+202
# 16    16  484  3.05E+26 3.15E+177    9.61E+203
# 17    17  483  5.67E+27 2.23E+177    1.27E+205
# 18    18  482  9.98E+28 1.58E+177    1.58E+206
# 19    19  481  1.67E+30 1.12E+177    1.87E+207
# 20    20  480  2.66E+31 7.92E+176    2.11E+208
# 21    21  479  4.06E+32 5.60E+176    2.27E+209
# 22    22  478  5.92E+33 3.95E+176    2.34E+210
# 23    23  477  8.29E+34 2.79E+176    2.32E+211
# 24    24  476  1.12E+36 1.97E+176    2.20E+212
# 25    25  475  1.45E+37 1.39E+176    2.01E+213
# 26    26  474  1.81E+38 9.79E+175    1.77E+214
# 27    27  473  2.18E+39 6.90E+175    1.51E+215
# 28    28  472  2.55E+40 4.85E+175    1.24E+216
# 29    29  471  2.88E+41 3.41E+175    9.85E+216
# ..   ...  ...       ...       ...          ...
# 471  471   29 7.06E+221  4.22E+36    2.98E+258
# 472  472   28 1.15E+222  5.37E+35    6.20E+257
# 473  473   27 1.88E+222  6.63E+34    1.25E+257
# 474  474   26 3.07E+222  7.92E+33    2.43E+256
# 475  475   25 5.00E+222  9.15E+32    4.58E+255
# 476  476   24 8.15E+222  1.02E+32    8.32E+254
# 477  477   23 1.33E+223  1.10E+31    1.46E+254
# 478  478   22 2.15E+223  1.14E+30    2.45E+253
# 479  479   21 3.50E+223  1.13E+29    3.97E+252
# 480  480   20 5.68E+223  1.08E+28    6.15E+251
# 481  481   19 9.21E+223  9.88E+26    9.10E+250
# 482  482   18 1.49E+224  8.61E+25    1.29E+250
# 483  483   17 2.42E+224  7.14E+24    1.73E+249
# 484  484   16 3.91E+224  5.62E+23    2.20E+248
# 485  485   15 6.32E+224  4.18E+22    2.64E+247
# 486  486   14 1.02E+225  2.93E+21    2.99E+246
# 487  487   13 1.65E+225  1.93E+20    3.18E+245
# 488  488   12 2.66E+225  1.18E+19    3.14E+244
# 489  489   11 4.28E+225  6.72E+17    2.88E+243
# 490  490   10 6.89E+225  3.52E+16    2.43E+242
# 491  491    9 1.11E+226  1.68E+15    1.87E+241
# 492  492    8 1.78E+226  7.29E+13    1.30E+240
# 493  493    7 2.86E+226  2.82E+12    8.07E+238
# 494  494    6 4.60E+226  9.57E+10    4.40E+237
# 495  495    5 7.37E+226  2.80E+09    2.07E+236
# 496  496    4 1.18E+227  6.87E+07    8.12E+234
# 497  497    3 1.89E+227  1.35E+06    2.56E+233
# 498  498    2 3.03E+227  2.01E+04    6.09E+231
# 499  499    1 4.85E+227  2.00E+02    9.69E+229
# 500  500    0 7.74E+227  1.00E+00    7.74E+227
#
# [501 rows x 5 columns]

# %%
factorial(500)
# Out:
# ...

# %%
float(factorial(500))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-138-300bc5141688> in <module>
# ----> 1 float(factorial(500))
#
# OverflowError: int too large to convert to float

# %%
sp.factorial(500, exact=True)
# Out:
# ...
